# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("/content/Motor_Vehicle_Collisions_-_Crashes_20240409 (1).csv")
# Out:
# <ipython-input-3-542748f9684c>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/Motor_Vehicle_Collisions_-_Crashes_20240409 (1).csv")

# %%
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2078796 entries, 0 to 2078795
# Data columns (total 29 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     object
#  1   CRASH TIME                     object
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
#  12  NUMBER OF PEDESTRIANS INJURED  int64
#  13  NUMBER OF PEDESTRIANS KILLED   int64
#  14  NUMBER OF CYCLIST INJURED      int64
#  15  NUMBER OF CYCLIST KILLED       int64
#  16  NUMBER OF MOTORIST INJURED     int64
# ...

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           646784
# ZIP CODE                          647034
# LATITUDE                          233855
# LONGITUDE                         233855
# LOCATION                          233855
# ON STREET NAME                    441491
# CROSS STREET NAME                 786131
# OFF STREET NAME                  1729678
# NUMBER OF PERSONS INJURED             18
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       6820
# CONTRIBUTING FACTOR VEHICLE 2     322530
# CONTRIBUTING FACTOR VEHICLE 3    1930213
# CONTRIBUTING FACTOR VEHICLE 4    2045241
# CONTRIBUTING FACTOR VEHICLE 5    2069700
# ...

# %%
nan_proportion = df.isna().sum() / len(df)
print(nan_proportion)
# Out:
# CRASH DATE                       0.000000
# CRASH TIME                       0.000000
# BOROUGH                          0.311134
# ZIP CODE                         0.311254
# LATITUDE                         0.112495
# LONGITUDE                        0.112495
# LOCATION                         0.112495
# ON STREET NAME                   0.212378
# CROSS STREET NAME                0.378166
# OFF STREET NAME                  0.832058
# NUMBER OF PERSONS INJURED        0.000009
# NUMBER OF PERSONS KILLED         0.000015
# NUMBER OF PEDESTRIANS INJURED    0.000000
# NUMBER OF PEDESTRIANS KILLED     0.000000
# NUMBER OF CYCLIST INJURED        0.000000
# NUMBER OF CYCLIST KILLED         0.000000
# NUMBER OF MOTORIST INJURED       0.000000
# NUMBER OF MOTORIST KILLED        0.000000
# CONTRIBUTING FACTOR VEHICLE 1    0.003281
# CONTRIBUTING FACTOR VEHICLE 2    0.155152
# CONTRIBUTING FACTOR VEHICLE 3    0.928524
# CONTRIBUTING FACTOR VEHICLE 4    0.983858
# ...

# %%
threshold = 0.5
data = df.loc[:, nan_proportion <= threshold]
data.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#    NUMBER OF PERSONS INJURED  ...  NUMBER OF PEDESTRIANS KILLED  \
# 0                        2.0  ...                             0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2078796 entries, 0 to 2078795
# Data columns (total 22 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     object
#  1   CRASH TIME                     object
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   NUMBER OF PERSONS INJURED      float64
#  10  NUMBER OF PERSONS KILLED       float64
#  11  NUMBER OF PEDESTRIANS INJURED  int64
#  12  NUMBER OF PEDESTRIANS KILLED   int64
#  13  NUMBER OF CYCLIST INJURED      int64
#  14  NUMBER OF CYCLIST KILLED       int64
#  15  NUMBER OF MOTORIST INJURED     int64
#  16  NUMBER OF MOTORIST KILLED      int64
# ...

# %%
data.isna().sum()
# Out:
# CRASH DATE                            0
# CRASH TIME                            0
# BOROUGH                          646784
# ZIP CODE                         647034
# LATITUDE                         233855
# LONGITUDE                        233855
# LOCATION                         233855
# ON STREET NAME                   441491
# CROSS STREET NAME                786131
# NUMBER OF PERSONS INJURED            18
# NUMBER OF PERSONS KILLED             31
# NUMBER OF PEDESTRIANS INJURED         0
# NUMBER OF PEDESTRIANS KILLED          0
# NUMBER OF CYCLIST INJURED             0
# NUMBER OF CYCLIST KILLED              0
# NUMBER OF MOTORIST INJURED            0
# NUMBER OF MOTORIST KILLED             0
# CONTRIBUTING FACTOR VEHICLE 1      6820
# CONTRIBUTING FACTOR VEHICLE 2    322530
# COLLISION_ID                          0
# VEHICLE TYPE CODE 1               13756
# VEHICLE TYPE CODE 2              397821
# dtype: int64

# %% [markdown]
# **To Clean the columns 'VEHICLE TYPE CODE 1'and 'VEHICLE TYPE CODE 2'**
#
# There are some vehicle type names which are named differently in the dataset. So we have to rename them properly.

# %%
print(data['VEHICLE TYPE CODE 1'])
# Out:
# 0                                        Sedan
# 1                                        Sedan
# 2                                        Sedan
# 3                                        Sedan
# 4                                          NaN
#                           ...
# 2078791    Station Wagon/Sport Utility Vehicle
# 2078792                              Ambulance
# 2078793    Station Wagon/Sport Utility Vehicle
# 2078794    Station Wagon/Sport Utility Vehicle
# 2078795                                  Sedan
# Name: VEHICLE TYPE CODE 1, Length: 2078796, dtype: object

# %%
unique_vehicle_type = data['VEHICLE TYPE CODE 1'].nunique()
print(unique_vehicle_type)
# Out:
# 1639

# %%
data['VEHICLE TYPE CODE 1'] = data['VEHICLE TYPE CODE 1'].str.upper()
vehicle_type = data['VEHICLE TYPE CODE 1'].nunique()
print(vehicle_type)
# Out:
# <ipython-input-14-32b57a20f76c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['VEHICLE TYPE CODE 1'] = data['VEHICLE TYPE CODE 1'].str.upper()
# 1136

# %%
unique_vehicle_type2 = data['VEHICLE TYPE CODE 2'].nunique()
print(unique_vehicle_type)
# Out:
# 1639

# %%
data['VEHICLE TYPE CODE 2'] = data['VEHICLE TYPE CODE 2'].str.upper()
vehicle_type2 = data['VEHICLE TYPE CODE 2'].nunique()
print(vehicle_type2)
# Out:
# <ipython-input-16-dbfd25cae5ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['VEHICLE TYPE CODE 2'] = data['VEHICLE TYPE CODE 2'].str.upper()
# 1261

# %%
data.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#    NUMBER OF PERSONS INJURED  ...  NUMBER OF PEDESTRIANS KILLED  \
# 0                        2.0  ...                             0
# ...

# %%
total_vehicle_types = pd.concat([data['VEHICLE TYPE CODE 1'], data['VEHICLE TYPE CODE 2']])

# %%
tot_vehicle_types = total_vehicle_types.unique()
print(tot_vehicle_types)
# Out:
# ['SEDAN' nan 'DUMP' ... 'GARBAGE VE' 'CON ED BOX' 'MARSH ,OPE']

# %%
total_vehicle_types.dropna(inplace=True)
type_counts = total_vehicle_types.value_counts()
print(type_counts.head(50))
# Out:
# SEDAN                                  982613
# STATION WAGON/SPORT UTILITY VEHICLE    781928
# PASSENGER VEHICLE                      734813
# SPORT UTILITY / STATION WAGON          320495
# TAXI                                   148600
# UNKNOWN                                101551
# PICK-UP TRUCK                           88404
# 4 DR SEDAN                              70256
# BUS                                     66374
# VAN                                     66300
# BOX TRUCK                               52642
# BIKE                                    46690
# OTHER                                   44668
# LARGE COM VEH(6 OR MORE TIRES)          28084
# SMALL COM VEH(4 TIRES)                  26178
# MOTORCYCLE                              22749
# TRACTOR TRUCK DIESEL                    20614
# BICYCLE                                 19113
# LIVERY VEHICLE                          18939
# AMBULANCE                               10964
# ...

# %%
vehicle_type_map = {
    'STATION WAGON/SPORT UTILITY VEHICLE': 'SUV',
    'SPORT UTILITY / STATION WAGON': 'SUV',
    '4 DR SEDAN': 'SEDAN',
    '2 DR SEDAN': 'SEDAN',
    'PASSENGER VEHICLE': 'SEDAN',
    'SMALL COM VEH(4 TIRES) ': 'SMALL COMMERCIAL VEHICLE',
    'SMALL COM VEH(4 TIRES)': 'SMALL COMMERCIAL VEHICLE',
    'LARGE COM VEH(6 OR MORE TIRES)': 'LARGE COMMERCIAL VEHICLE',
    'TRACTOR TRUCK DIESEL': 'TRACTOR TRUCK',
    'TRACTOR TRUCK GASOLINE': 'TRACTOR TRUCK',
    'MOTORSCOOTER': 'SCOOTER',
    'MOTORBIKE': 'MOTORCYCLE',
    'E-BIKE': 'ELECTRIC BIKE',
    'E-SCOOTER': 'ELECTRIC SCOOTER',
    'AMBUL': 'AMBULANCE',
    'FIRE' : 'FIRE TRUCK',
    'GARBAGE OR REFUSE' : 'GARBAGE TRUCK',
    'E-BIK' : 'ELECTRIC BIKE',
    'E-SCO' : 'ELECTRIC SCOOTER',
    'OTHER' : 'UNKNOWN',
    'DUMP' : 'GARBAGE TRUCK',
    'UNKNO' : 'UNKNOWN',
    'UNK' : 'UNKNOWN',
    'PICK-UP TRUCK' : 'PICK-UP',
    'TRACT' : 'TRACTOR TRUCK',
    'TRAIL' : 'TRAILER',
    'AMBU' : 'AMBULANCE',
    'TOW TRUCK / WRECKER' : 'TOW TRUCK',
    'REFRIGERATED VAN' : 'VAN',
    'BOX TRUCK' : 'TRUCK',
    'TRACTOR TRUCK' : 'TRUCK',
    'GARBAGE TRUCK' : 'TRUCK',
    'TOW TRUCK' : 'TRUCK',
    'FIRE TRUCK' : 'FDNY',
    'ARMORED TRUCK' : 'TRUCK',
    'BEVERAGE TRUCK' : 'TRUCK',
    'FIRETRUCK' : 'FDNY',
    'TOW T' : 'TRUCK',
    'FIRET' : 'FDNY',
    'SCHOO' : 'SCHOOL BUS',
    'FORKL' : 'FORKLIFT',
    'BOX T' : 'TRUCK',
    'BIKE' : 'MOTORCYCLE',
    'SCOOTER' : 'MOTORCYCLE',
    'SCOOT' : 'MOTORCYCLE',
    'MOPED' : 'MOTORCYCLE',
    'ELECTRIC BIKE' : 'MOTORCYCLE',
    'ELECTRIC SCOOTER' : 'MOTORCYCLE',
    'AMB' : 'AMBULANCE',
    'FDNY TRUCK ' : 'FDNY',
    'PALLET' : 'FORKLIFT',
    'PICKUP WITH MOUNTED CAMPER' : 'PICK-UP',
    'MINIBIKE' : 'MOTORCYCLE',
    'ELECT' : 'MOTORCYCLE',
    'COMMERCIAL' : 'SMALL COMMERCIAL VEHICLE',
    'COMME' : 'SMALL COMMERCIAL VEHICLE',
    'COM' : 'SMALL COMMERCIAL VEHICLE',
    'GARBA' : 'TRUCK',
    'FDNY AMBUL' : 'AMBULANCE',
    'VAN CAMPER' : 'VAN',
    'MOTOR' : 'MOTORCYCLE',
    'FDNY FIRE' : 'FDNY',
    'FDNY TRUCK' : 'FDNY',
    'FORK' : 'FORKLIFT',
    'PICK' : 'PICK-UP',
    'FLAT' : 'FLAT RACK',
    'DELV' : 'DELIV',
    'PICK UP' : 'PICK-UP',
    'PICKU' : 'PICK-UP',
    'GARBAGE TR' : 'TRUCK',
    'MINICYCLE' : 'BICYCLE'


}

# %%
total_vehicle_types.replace(vehicle_type_map, inplace=True)
type_counts = total_vehicle_types.value_counts()
print(type_counts.head(50))
# Out:
# SEDAN                       1792266
# SUV                         1102447
# TAXI                         148600
# UNKNOWN                      147198
# MOTORCYCLE                   112976
# TRUCK                         94321
# PICK-UP                       88679
# VAN                           67373
# BUS                           66374
# LARGE COMMERCIAL VEHICLE      28084
# SMALL COMMERCIAL VEHICLE      26538
# LIVERY VEHICLE                18939
# AMBULANCE                     12193
# CONVERTIBLE                    6214
# FLAT BED                       5022
# PK                             4760
# CARRY ALL                      3972
# FDNY                           2937
# CHASSIS CAB                    1728
# TANKER                         1600
# CONCRETE MIXER                 1035
# TRAILER                         861
# FLAT RACK                       720
# 3-DOOR                          597
# SCHOOL BUS                      594
# LIMO                            463
# ...
