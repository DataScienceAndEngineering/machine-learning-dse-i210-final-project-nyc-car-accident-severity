# %%
#pip install geopy

# %%
from pathlib import Path
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim

# %%
# Define the path to the folder
folder_path = Path("C:/Users/crazy/OneDrive - The City College of New York/DSE I2100 - Applied Machine Learning and Data Mining/Project")
csv_file = folder_path.glob("*.csv").__next__()

# Load CSV file into DataFrame
df = pd.read_csv(csv_file)
# Out:
# C:\Users\crazy\AppData\Local\Temp\ipykernel_36496\545171645.py:6: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)

# %%
df.head() # don't need location (redundant)
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# ...

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2070069 entries, 0 to 2070068
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   CRASH DATE                     2070069 non-null  object
#  1   CRASH TIME                     2070069 non-null  object
#  2   BOROUGH                        1426009 non-null  object
#  3   ZIP CODE                       1425759 non-null  object
#  4   LATITUDE                       1836747 non-null  float64
#  5   LONGITUDE                      1836747 non-null  float64
#  6   LOCATION                       1836747 non-null  object
#  7   ON STREET NAME                 1631008 non-null  object
#  8   CROSS STREET NAME              1288388 non-null  object
#  9   OFF STREET NAME                346688 non-null   object
#  10  NUMBER OF PERSONS INJURED      2070051 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           644060
# ZIP CODE                          644310
# LATITUDE                          233322
# LONGITUDE                         233322
# LOCATION                          233322
# ON STREET NAME                    439061
# CROSS STREET NAME                 781681
# OFF STREET NAME                  1723381
# NUMBER OF PERSONS INJURED             18
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       6764
# CONTRIBUTING FACTOR VEHICLE 2     320441
# CONTRIBUTING FACTOR VEHICLE 3    1922275
# CONTRIBUTING FACTOR VEHICLE 4    2036722
# CONTRIBUTING FACTOR VEHICLE 5    2061045
# ...

# %%
df.describe()
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.836747e+06  1.836747e+06               2.070051e+06
# mean   4.062766e+01 -7.375207e+01               3.091991e-01
# std    1.981103e+00  3.724478e+00               6.995734e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066782e+01 -7.397485e+01               0.000000e+00
# 50%    4.072084e+01 -7.392727e+01               0.000000e+00
# 75%    4.076960e+01 -7.386673e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              2.070038e+06                   2.070069e+06
# mean               1.489828e-03                   5.643387e-02
# std                4.071430e-02                   2.438690e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# ...

# %%
print(len(df['CONTRIBUTING FACTOR VEHICLE 1'].unique()))
df['CONTRIBUTING FACTOR VEHICLE 1'].unique()
# Out:
# 62
# array(['Aggressive Driving/Road Rage', 'Pavement Slippery',
#        'Following Too Closely', 'Unspecified', nan, 'Passing Too Closely',
#        'Driver Inexperience', 'Passing or Lane Usage Improper',
#        'Turning Improperly', 'Unsafe Lane Changing', 'Unsafe Speed',
#        'Reaction to Uninvolved Vehicle', 'Steering Failure',
#        'Traffic Control Disregarded', 'Other Vehicular',
#        'Driver Inattention/Distraction', 'Oversized Vehicle',
#        'Pedestrian/Bicyclist/Other Pedestrian Error/Confusion',
#        'Alcohol Involvement', 'View Obstructed/Limited',
#        'Failure to Yield Right-of-Way', 'Illnes', 'Lost Consciousness',
#        'Brakes Defective', 'Backing Unsafely', 'Glare',
#        'Passenger Distraction', 'Fell Asleep', 'Obstruction/Debris',
#        'Tinted Windows', 'Animals Action', 'Drugs (illegal)',
#        'Pavement Defective', 'Other Lighting Defects',
#        'Outside Car Distraction', 'Driverless/Runaway Vehicle',
# ...

# %%
test = df.copy()
test['CONTRIBUTING FACTOR VEHICLE 1'] = test['CONTRIBUTING FACTOR VEHICLE 1'].str.lower()

# %%
print(len(test['CONTRIBUTING FACTOR VEHICLE 1'].unique()))
test['CONTRIBUTING FACTOR VEHICLE 1'].unique()
# Out:
# 60
# array(['aggressive driving/road rage', 'pavement slippery',
#        'following too closely', 'unspecified', nan, 'passing too closely',
#        'driver inexperience', 'passing or lane usage improper',
#        'turning improperly', 'unsafe lane changing', 'unsafe speed',
#        'reaction to uninvolved vehicle', 'steering failure',
#        'traffic control disregarded', 'other vehicular',
#        'driver inattention/distraction', 'oversized vehicle',
#        'pedestrian/bicyclist/other pedestrian error/confusion',
#        'alcohol involvement', 'view obstructed/limited',
#        'failure to yield right-of-way', 'illnes', 'lost consciousness',
#        'brakes defective', 'backing unsafely', 'glare',
#        'passenger distraction', 'fell asleep', 'obstruction/debris',
#        'tinted windows', 'animals action', 'drugs (illegal)',
#        'pavement defective', 'other lighting defects',
#        'outside car distraction', 'driverless/runaway vehicle',
# ...

# %%
test['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()
# Out:
# unspecified                                              705449
# driver inattention/distraction                           413948
# failure to yield right-of-way                            122906
# following too closely                                    110586
# backing unsafely                                          76562
# other vehicular                                           64238
# passing or lane usage improper                            57625
# passing too closely                                       51512
# turning improperly                                        51115
# fatigued/drowsy                                           47397
# unsafe lane changing                                      40656
# traffic control disregarded                               36716
# driver inexperience                                       32389
# unsafe speed                                              28922
# alcohol involvement                                       22618
# ...

# %%
test['ON STREET NAME'].value_counts()
# Out:
# BROADWAY                            17277
# ATLANTIC AVENUE                     15322
# BELT PARKWAY                        13543
# 3 AVENUE                            12476
# NORTHERN BOULEVARD                  11965
#                                     ...
# E 45TH STREET                           1
# 8th avenue                              1
# VANCORTLANDT  Park South                1
# BUSSING PLACE                           1
# NORMAL ROAD                             1
# Name: ON STREET NAME, Length: 18392, dtype: int64

# %%
test["BOROUGH"].value_counts()
# Out:
# BROOKLYN         453423
# QUEENS           382367
# MANHATTAN        319612
# BRONX            210752
# STATEN ISLAND     59855
# Name: BOROUGH, dtype: int64

# %%
test.head(10)
# Out:
#    CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39        NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45        NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55        NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35   BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13   BROOKLYN  11233.0  40.683304 -73.917274
# 5  04/14/2021      12:47        NaN      NaN        NaN        NaN
# 6  12/14/2021      17:05        NaN      NaN  40.709183 -73.956825
# 7  12/14/2021       8:17      BRONX  10475.0  40.868160 -73.831480
# 8  12/14/2021      21:10   BROOKLYN  11207.0  40.671720 -73.897100
# 9  12/14/2021      14:58  MANHATTAN  10017.0  40.751440 -73.973970
#
#                   LOCATION                ON STREET NAME CROSS STREET NAME  \
# 0                      NaN         WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN       QUEENSBORO BRIDGE UPPER               NaN
# ...

# %%
geolocator = Nominatim(user_agent="accident_severity_prediction")

def reverse_geocode(lat, lon):
    try:
        location = geolocator.reverse((lat, lon))
        address = location.raw
        return address
    except:
        return None

# %%
latitude = 40.751440  # Example latitude
longitude = -73.973970  # Example longitude

street_address = reverse_geocode(latitude, longitude)
print("Street Address:", street_address)
# Out:
# Street Address: {'place_id': 15441054, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4555833813, 'lat': '40.7516142', 'lon': '-73.9740562', 'class': 'amenity', 'type': 'fast_food', 'place_rank': 30, 'importance': 9.99999999995449e-06, 'addresstype': 'amenity', 'name': 'Pita Yeero', 'display_name': 'Pita Yeero, 684, 3rd Avenue, Beekman, Manhattan Community Board 6, Manhattan, New York County, City of New York, New York, 10017, United States', 'address': {'amenity': 'Pita Yeero', 'house_number': '684', 'road': '3rd Avenue', 'neighbourhood': 'Beekman', 'suburb': 'Manhattan', 'county': 'New York County', 'city': 'City of New York', 'state': 'New York', 'ISO3166-2-lvl4': 'US-NY', 'postcode': '10017', 'country': 'United States', 'country_code': 'us'}, 'boundingbox': ['40.7515642', '40.7516642', '-73.9741062', '-73.9740062']}

# %%
print(type(street_address))
# Out:
# <class 'dict'>

# %%
def reverse_geocode(lat, lon):
    try:
        location = geolocator.reverse((lat, lon))
        address = location.raw
        borough = address.get('address', {}).get('suburb')
        zipcode = address.get('address', {}).get('postcode')
        on_street_name = address.get('address', {}).get('road')
        return [borough, zipcode, on_street_name]
    except:
        return [np.nan, np.nan, np.nan]

# %%
street_address2 = reverse_geocode(40.683304, -73.917274)
print("Street Address:", street_address2)
# Out:
# Street Address: ['Brooklyn', '11233', 'Decatur Street']

# %%
test2 = test.head(50).copy()
test3 = test.copy()

# %%
# Function to reverse geocode latitude and longitude
def reverse_geocode(row):
    lat = row['LATITUDE']
    lon = row['LONGITUDE']

    try:
        location = geolocator.reverse((lat, lon))
        address = location.raw
        borough = address.get('address', {}).get('suburb')
        zipcode = address.get('address', {}).get('postcode')
        on_street_name = address.get('address', {}).get('road')
        return [borough, zipcode, on_street_name]
    except:
        return [np.nan, np.nan, np.nan]

# %%
# Apply the reverse_geocode function to each row of the dataframe
#new_values = test[['LATITUDE', 'LONGITUDE']].apply(reverse_geocode, axis=1, result_type='expand')

# Replace NaN values in 'borough', 'zipcode', and 'address' columns with the corresponding values from the reverse_geocode function
#test['borough'].fillna(new_values[0], inplace=True)
#test['zipcode'].fillna(new_values[1], inplace=True)
#test['address'].fillna(new_values[2], inplace=True)

# %%
# Apply the reverse_geocode function to each row of the dataframe
new_values = test2[['LATITUDE', 'LONGITUDE']].apply(reverse_geocode, axis=1, result_type='expand')

# Replace NaN values in 'borough', 'zipcode', and 'address' columns with the corresponding values from the reverse_geocode function
test2['BOROUGH'].fillna(new_values[0], inplace=True)
test2['ZIP CODE'].fillna(new_values[1], inplace=True)
test2['ON STREET NAME'].fillna(new_values[2], inplace=True)

# %%
test2.head(20)
# Out:
#     CRASH DATE CRASH TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0   09/11/2021       2:39            NaN      NaN        NaN        NaN
# 1   03/26/2022      11:45            NaN      NaN        NaN        NaN
# 2   06/29/2022       6:55            NaN      NaN        NaN        NaN
# 3   09/11/2021       9:35       BROOKLYN  11208.0  40.667202 -73.866500
# 4   12/14/2021       8:13       BROOKLYN  11233.0  40.683304 -73.917274
# 5   04/14/2021      12:47            NaN      NaN        NaN        NaN
# 6   12/14/2021      17:05       Brooklyn    11249  40.709183 -73.956825
# 7   12/14/2021       8:17          BRONX  10475.0  40.868160 -73.831480
# 8   12/14/2021      21:10       BROOKLYN  11207.0  40.671720 -73.897100
# 9   12/14/2021      14:58      MANHATTAN  10017.0  40.751440 -73.973970
# 10  12/13/2021       0:34  Queens County    11385  40.701275 -73.888870
# 11  12/14/2021      16:50         QUEENS  11413.0  40.675884 -73.755770
# ...

# %%
test3.head(20)
# Out:
#     CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0   09/11/2021       2:39        NaN      NaN        NaN        NaN
# 1   03/26/2022      11:45        NaN      NaN        NaN        NaN
# 2   06/29/2022       6:55        NaN      NaN        NaN        NaN
# 3   09/11/2021       9:35   BROOKLYN  11208.0  40.667202 -73.866500
# 4   12/14/2021       8:13   BROOKLYN  11233.0  40.683304 -73.917274
# 5   04/14/2021      12:47        NaN      NaN        NaN        NaN
# 6   12/14/2021      17:05        NaN      NaN  40.709183 -73.956825
# 7   12/14/2021       8:17      BRONX  10475.0  40.868160 -73.831480
# 8   12/14/2021      21:10   BROOKLYN  11207.0  40.671720 -73.897100
# 9   12/14/2021      14:58  MANHATTAN  10017.0  40.751440 -73.973970
# 10  12/13/2021       0:34        NaN      NaN  40.701275 -73.888870
# 11  12/14/2021      16:50     QUEENS  11413.0  40.675884 -73.755770
# 12  12/14/2021       8:30        NaN      NaN        NaN        NaN
# ...
